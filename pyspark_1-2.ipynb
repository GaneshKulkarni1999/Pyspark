# %%
pip install pyspark
# Out:
# ...
#
# ...

# %%
import pyspark

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Ganesh Kulkarni\Downloads\global_health_data.csv")
df
# Out:
#              Country  Year         Disease Name Disease Category  \
# 0              Italy  2013              Malaria      Respiratory
# 1             France  2002                Ebola        Parasitic
# 2             Turkey  2015             COVID-19          Genetic
# 3          Indonesia  2011  Parkinson's Disease       Autoimmune
# 4              Italy  2013         Tuberculosis          Genetic
# ...              ...   ...                  ...              ...
# 999995  Saudi Arabia  2021  Parkinson's Disease       Infectious
# 999996  Saudi Arabia  2013              Malaria      Respiratory
# 999997           USA  2016                 Zika      Respiratory
# 999998       Nigeria  2020               Asthma          Chronic
# 999999     Indonesia  2004               Asthma     Neurological
#
#         Prevalence Rate  Incidence Rate  Mortality Rate Age Group  Gender  \
# 0                  0.95            1.55            8.42      0-18    Male
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Ganesh Kulkarni\Downloads\global_health_data.csv")
df
# Out:
#              Country  Year         Disease Name Disease Category  \
# 0              Italy  2013              Malaria      Respiratory
# 1             France  2002                Ebola        Parasitic
# 2             Turkey  2015             COVID-19          Genetic
# 3          Indonesia  2011  Parkinson's Disease       Autoimmune
# 4              Italy  2013         Tuberculosis          Genetic
# ...              ...   ...                  ...              ...
# 999995  Saudi Arabia  2021  Parkinson's Disease       Infectious
# 999996  Saudi Arabia  2013              Malaria      Respiratory
# 999997           USA  2016                 Zika      Respiratory
# 999998       Nigeria  2020               Asthma          Chronic
# 999999     Indonesia  2004               Asthma     Neurological
#
#         Prevalence Rate  Incidence Rate  Mortality Rate Age Group  Gender  \
# 0                  0.95            1.55            8.42      0-18    Male
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('testing').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.47:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>testing</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv(r"C:\Users\Ganesh Kulkarni\Downloads\4 recoreds correct final2.csv", header=True)
df_pyspark.show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
df_pyspark=spark.read.option('header','true').csv(r"C:\Users\Ganesh Kulkarni\Downloads\4 recoreds correct final2.csv")

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema
# Out:
# <bound method DataFrame.printSchema of DataFrame[Name: string, Father's/Husband's Name: string, House Number: string, Age: string, Gender: string, EPIC No: string]>

# %%
df_pyspark.show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
#Read the Dataset
df_pyspark=spark.read.option('header','true').csv(r"C:\Users\Ganesh Kulkarni\Downloads\final2.csv",inferSchema=True)

# %%
#Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Father's/Husband's Name: string (nullable = true)
#  |-- House Number: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- EPIC No: string (nullable = true)

# %%
df_pyspark=spark.read.csv(r"C:\Users\Ganesh Kulkarni\Downloads\final2.csv",header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
#Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Father's/Husband's Name: string (nullable = true)
#  |-- House Number: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- EPIC No: string (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', "Father's/Husband's Name", 'House Number', 'Age', 'Gender', 'EPIC No']

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='AMOL SURESH CHAKHALE', Father's/Husband's Name='SURESH CHAKHALE', House Number='N/A', Age=28, Gender='Male', EPIC No='UUK7899438'),
#  Row(Name='JAYSHRI BABURAO GAYKWAD', Father's/Husband's Name='BABURAO GAYKWAD', House Number='N/A', Age=57, Gender='Female', EPIC No='UUK7899404'),
#  Row(Name='Surekha Parshuram Pawar', Father's/Husband's Name='Parshuram Pawar', House Number='N/A', Age=46, Gender='Female', EPIC No='UUK7514839')]

# %%
df_pyspark.show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
df_pyspark.select('Name').show()
# Out:
# +--------------------+
# |                Name|
# +--------------------+
# |AMOL SURESH CHAKHALE|
# |JAYSHRI BABURAO G...|
# |Surekha Parshuram...|
# |JAYASHRI TRIMABAK...|
# |  RANJIT KUSUM Valke|
# |Kalyani Ganesh Walke|
# |        Shobha Kadam|
# |priyanka Dadabhau...|
# +--------------------+

# %%
df_pyspark.select(['Name','Gender']).show()
# Out:
# +--------------------+------+
# |                Name|Gender|
# +--------------------+------+
# |AMOL SURESH CHAKHALE|  Male|
# |JAYSHRI BABURAO G...|Female|
# |Surekha Parshuram...|Female|
# |JAYASHRI TRIMABAK...|Female|
# |  RANJIT KUSUM Valke|  Male|
# |Kalyani Ganesh Walke|Female|
# |        Shobha Kadam|Female|
# |priyanka Dadabhau...|Female|
# +--------------------+------+

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'),
#  ("Father's/Husband's Name", 'string'),
#  ('House Number', 'string'),
#  ('Age', 'int'),
#  ('Gender', 'string'),
#  ('EPIC No', 'string')]

# %%
df_pyspark.describe().show()
# Out:
# +-------+--------------------+-----------------------+------------+------------------+------+----------+
# |summary|                Name|Father's/Husband's Name|House Number|               Age|Gender|   EPIC No|
# +-------+--------------------+-----------------------+------------+------------------+------+----------+
# |  count|                   8|                      8|           8|                 8|     8|         8|
# |   mean|                NULL|                   NULL|        NULL|              36.5|  NULL|      NULL|
# | stddev|                NULL|                   NULL|        NULL|12.739141034061687|  NULL|      NULL|
# |    min|AMOL SURESH CHAKHALE|        BABURAO GAYKWAD|           -|                25|Female|UUK7514839|
# |    max|priyanka Dadabhau...|        TRIMABAK SHWOSE|         N/A|                57|  Male|UUK8322901|
# +-------+--------------------+-----------------------+------------+------------------+------+----------+

# %%
#Adding columns in data frame

df_pyspark.withColumn('Voter_id',df_pyspark['EPIC No']+2).show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+--------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|Voter_id|
# +--------------------+-----------------------+------------+---+------+----------+--------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|    NULL|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|    NULL|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|    NULL|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|    NULL|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|    NULL|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|    NULL|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|    NULL|
# ...

# %%
#Drop cloumns in data-frame
df_pyspark.drop('Voter_id').show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|   EPIC No|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
#Rename the cloumns
df_pyspark.withColumnRenamed('EPIC No','Voter_id').show()
# Out:
# +--------------------+-----------------------+------------+---+------+----------+
# |                Name|Father's/Husband's Name|House Number|Age|Gender|  Voter_id|
# +--------------------+-----------------------+------------+---+------+----------+
# |AMOL SURESH CHAKHALE|        SURESH CHAKHALE|         N/A| 28|  Male|UUK7899438|
# |JAYSHRI BABURAO G...|        BABURAO GAYKWAD|         N/A| 57|Female|UUK7899404|
# |Surekha Parshuram...|        Parshuram Pawar|         N/A| 46|Female|UUK7514839|
# |JAYASHRI TRIMABAK...|        TRIMABAK SHWOSE|         N/A| 31|Female|UUK7899396|
# |  RANJIT KUSUM Valke|            KUSUM Valke|         N/A| 27|  Male|UUK7899255|
# |Kalyani Ganesh Walke|           Ganesh Walke|         N/A| 27|Female|UUK7970494|
# |        Shobha Kadam|           Sanjay Kadam|           -| 51|Female|UUK8322901|
# |priyanka Dadabhau...|       Dadasaheb Shinde|           -| 25|Female|UUK7899446|
# ...

# %%
from pyspark.sql import SparkSession
spark=Sparksession.builder.appName('NEW Spark').getOrCreate()

# %%
df_pyspark.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_pyspark.printSchema()
#
# NameError: name 'df_pyspark' is not defined
